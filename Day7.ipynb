# %%
li=[5,3,2,1]
li.sort()
print(li)
# Out:
# [1, 2, 3, 5]

# %%
li=[1,2,3,4,5,6]
li.pop()
print(li)
# Out:
# [1, 2, 3, 4, 5]

# %%
li=[1,2,3,4,5]
li.pop(3)
print(li)
# Out:
# [1, 2, 3, 5]

# %%
l=[1,2,3]
li=[4,5,6]
l.extend(li)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # dictionaries

# %%
d={"name":'gitam',"email":'gitam@gitam'}
print(d)
print(type(d))
# Out:
# {'name': 'gitam', 'email': 'gitam@gitam'}
# <class 'dict'>

# %%
d['name']='python'
print(d)
# Out:
# {'name': 'python', 'email': 'gitam@gitam'}

# %%
del d['email']
print(d)
# Out:
# {'name': 'python'}

# %% [markdown]
# # tuple

# %%
li=[1,2,3,4,5,6,7]
def leastno(li):
    li.sort()
    return li[-1]
print(leastno(li))
# Out:
# 7

# %% [markdown]
# # project building a contact application using python
#
# - contact appication
# - add contact details
# - search contact details
# - list all the contacts
# - name1:value
# - name2:value
# - modify or update the contact details
# - delete the contact details

# %%
contacts={ }
def addcontact(name,phone):
    if name not in contacts:
        contacts[name]=phone
        print('contact details are added succesfully')
    else:
        print('contact already exists')
    return
addcontact('jhansi','9874561230')

def searchcontact(name):
    if name  in contacts:
        print(name,' :',contacts[name])
    else:
        print(name,'doesnot exists')
    return
searchcontact('jhansi')
# Out:
# contact details are added succesfully
# jhansi  : 9874561230

# %%
def searchcontact(name):
    if name  in contacts:
        print(name,' :',contacts[name])
    else:
        print(name,'doesnot exists')
    return
searchcontact('jhansi')
# Out:
# jhansi  : 9874561230

# %%
def importcontact(name):
    contacts.update(newcontact)
    print(len(newcontact.keys()),"contacts are added")
    return
newcontact={'divya':1234567890}
importcontact(newcontact)
# Out:
# 1 contacts are added

# %%
def delcontact(name):
    if name in contacts:
        del contacts[name]
        print(name,'deleted sucessfully')
    else:
        print(name,'not present')
delcontact('divya')
# Out:
# divya deleted sucessfully
